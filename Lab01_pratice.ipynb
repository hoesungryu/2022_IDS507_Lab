# %% [markdown]
# # 💻IDS507 | Lab01_practice
# <font size=5><b>Python introduction<b></font>
# <div align='right'>TA: 류 회 성(Hoe Sung Ryu)</div>
#
# ## Concepts | 오늘 배울 개념
# ---
# - 파이썬 기본 문법을 익힌다.
#   1. 변수
#   1. 문자열
#   1. 수치형
#   1. 논리형
#   1. 리스트, 딕셔너리
#   1. 조건문과 반복문
#   1. 함수

# %% [markdown]
# ## 📌1. 파이썬 기본문법

# %% [markdown]
# ### 1) 변수
#
# - 할당과 동시에 형태가 정해짐
#
# <img src='https://t1.daumcdn.net/cfile/tistory/221A3E3E58E49E303A'>

# %%
x = 10 
print(x)
print(type(x))

# %%
Variable = '1'

# %%
1_variable = '1'

# %% [markdown]
# ### 2) 문자열
#
# <img src='https://media.vlpt.us/images/joygoround/post/f70317e0-ab63-4b2d-9b54-dab83fa2c759/image.png'>

# %%
x = '10'
print(x)
print(type(x))

# %%
# f-string
print(f'x 는 {x} 입니다')

# %%
print('류회성 ')

# %%
print('류회성'.rstrip())

# %% [markdown]
# ### 3) 수치형

# %%
print(10 + 10) 
print(10 * 10) 
print(10 / 10) 
print(10 ** 2) 
print(10 % 2) # 나머지 
print(10 //2 ) # 몫

# %% [markdown]
# ### 4) 논리형

# %%
print(False and True)
print(True and True)
print(True and False)
print(False and False)

# %% [markdown]
# ### 5) 리스트 & 딕셔너리
#
# #### 1) 리스트
# <img src='https://cdn.programiz.com/sites/tutorial2program/files/python-list-index.png' width=70%>

# %%
my_list = ['p','r','o','b','e']
my_list

my_list = list('probe')
my_list

print(len(my_list))

# %% [markdown]
# <img src='https://t1.daumcdn.net/cfile/tistory/99A6FD33599C471A20'>

# %% [markdown]
# ### 2) 딕셔너리
#
# <img src='https://programmathically.com/wp-content/uploads/2021/05/dictionary-1024x554.png' width=70%>

# %%
my_dict = {'a': 1, "b": 2}
print(my_dict.keys())
print(my_dict.values())
print(my_dict['a'])

# %% [markdown]
# ### 6) 조건문과 반복문

# %% [markdown]
# #### 1) 조건문

# %%
my_value = float(input())
if my_value >= 10:
  print('10보다 크거나 같다')
else:
  print('10보다 작다')

# %%
my_value = float(input())
if my_value >= 10:
  print('10보다 크거나 같다')
elif 5<= my_value < 10:
  print('5보다 크거나 10보다작다')
else:
  print('5보다 작다')

# %% [markdown]
# #### 2) 반복문

# %%
for i in [1,2,3,4,5]:
  print(i)

# %% [markdown]
# ### 7) 함수
#
# ```
# # 몫 과 나머지 를 출력하는 함수만들어보기
# ```

# %% [markdown]
# -------------------------------------------------------------------
# ## 문제
#
# ###Q1. `He's drinking coeffee` 를 출력하시오. (문자열)

# %% [markdown]
# ###Q2. a에 3을 할당하고, 3이랑 같은지 확인

# %%
a = 3 
a == 3
# Out:
# True

# %%
a is 3
# Out:
# True

# %%
a = 431
b = 431

a is b
# Out:
# False

# %% [markdown]
# ###Q3. 문자열 "15.79"를 실수(float) 타입으로 바꾸기

# %% [markdown]
# ###Q4. 다음 food 리스트에서 4번째 원소 출력하기
#
# ```
# food = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면", "소시지", "라면", "팥빙수", "김치전"]
# ```

# %% [markdown]
# ###Q5. 다음 icecream 딕셔너리에서 폴라포 가격 출력하기
#
# icecream = {'탱크보이': 1200, '폴라포': 500, '빵빠레': 2000, '월드콘': 1500, '메로나': 700}

# %% [markdown]
# ###Q6. 다음 price_list 에 각 원소를 10을 나누어 출력하시오. (for문)
#
# price_list = [32100, 32150, 32000, 32500]

# %% [markdown]
# ###Q7. 두개의 인풋을 받아 덧셈을 하는 함수 만드시오.

# %%
def my_print (a, b) :
    print("왼쪽:", a)
    print("오른쪽:", b)

my_print(b=100, a=200)
